# %%
print("Vou terminar esse curso e postar no Linkedin!")
# Out:
# Vou terminar esse curso e postar no Linkedin!

# %% [markdown]
# escrevendo coisas

# %%
print("hello world")
# Out:
# hello world

# %%
print(23)
# Out:
# 23
