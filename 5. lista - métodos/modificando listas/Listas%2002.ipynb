# %% [markdown]
# # Listas em Python
#
# ## Estrutura:
#
# lista = [valor, valor, valor, valor, ...]
#
# lista[i] -> é o valor de índice i da lista. <br>
# Obs: Lembre que no python o índice começa em 0, então o primeiro item de uma lista é o item lista[0]
#
# Para substituir um valor de uma lista você pode fazer:<br>
# lista[i] = novo_valor
#
# Listas de Produtos de uma Loja:

# %%
produtos = ['tv', 'celular', 'mouse', 'teclado', 'tablet']

# %% [markdown]
# Lista de Unidades Vendidas de cada Produto da Loja

# %%
vendas = [1000, 1500, 350, 270, 900]

# %% [markdown]
# ### Nesse caso, as listas funcionam da seguinte forma:

# %% [raw]
# produtos = ['tv', 'celular', 'mouse', 'teclado', 'tablet']
#               0 ,      1   ,    2   ,     3    ,     4
# vendas = [  1000,    1500  ,   350  ,    270   ,    900  ]

# %%
# texto atual = 'lira@gmail.com'
# vamos supor que eu quero mudar para = "lara@gmail.com" trocar o 'i' pelo 'a'

texto = 'lira@gmail.com'
novo_texto = texto.replace("i","a")
print(novo_texto)

#agora sim, no Python as strings são IMUTÁVEIS, isso significa que elas não podem ser "mexidas"
# o que da pra fazer é atribuir uma nova variável ou escrever ela dnv pra substituir usando o método .replace
# Out:
# lara@gmaal.com
