# %% [markdown]
# # Meu primeiro código Python ipynb
# vamos lá

# %%
print("vamos lá, vai dar certo")
# Out:
# vamos lá, vai dar certo

# %%
print("vamos terminar esse curso, vai dar certo")
# Out:
# vamos terminar esse curso, vai dar certo
