# %% [markdown]
# # Tipos de Variáveis em Python
# Uma variável é um objeto, afinal tudo é um objeto em Python
#
# int -> inteiro
# string -> texto
# float -> números com casas decimais (ponto flutuante)
# bool ou boolean -> True ou False
#
# Obs: Variáveis em Python não são declaradas explicitamente, mas isso não significa que você deve ficar mudando o tempo todo
#
# Obs2: Cuidado com nomes restritos! reservados da sintaxe da linguagem

# %%
faturamento = "3000"
type(faturamento)
# Out:
# str

# %%
faturamento = 3000
type(faturamento)
# Out:
# int

# %%
faturamento = 3000.00
type(faturamento)
# Out:
# float

# %%
faturamentoAcima = True
type(faturamentoAcima)
# Out:
# bool
