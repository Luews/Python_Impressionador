# %%
faturamento = 2000
custo = 500
lucro = faturamento - custo

print(" O faturamento da loja foi de {} e o custo foi de {}, então o lucro foi de {}".format(faturamento, custo, lucro))
# Out:
#  O faturamento da loja foi de 2000 e o custo foi de 500, então o lucro foi de 1500

# %% [markdown]
# o .format é uma boa ideia também de misturar valores, lendo de uma linha só até pode ser a melhor opção
